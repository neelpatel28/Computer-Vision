# %% [markdown]
# # Color Palette

# %%
import cv2 
import numpy as np

# %% [markdown]
# ### Empty Function when trackbar is moved

# %%
def emptyFunction(a): 
	pass

# %% [markdown]
# ### Function to set Color using Trackbar

# %%
def ColorPalette(): 
	
	# blackwindow having 3 color chanels 
	image = np.zeros((512, 512, 3), np.uint8) 
	windowName ="Color Palette"
	
	# window name 
	cv2.namedWindow(windowName) 
	
	# Creating Trackbar
	cv2.createTrackbar('Red', windowName, 0, 255, emptyFunction) 
	cv2.createTrackbar('Green', windowName, 0, 255, emptyFunction) 
	cv2.createTrackbar('Blue', windowName, 0, 255, emptyFunction) 
	
	while(True): 
		cv2.imshow(windowName, image) 
		
		if cv2.waitKey(1) == ord('x'): 
			break
		
    # Values of B, G, R
		blue = cv2.getTrackbarPos('Blue', windowName) 
		green = cv2.getTrackbarPos('Green', windowName) 
		red = cv2.getTrackbarPos('Red', windowName) 
		
    # Merging all 3 colors
		image[:] = [blue, green, red] 
		# print(blue, green, red) 
		
	cv2.destroyAllWindows()
	
	print(f' Blue  : {blue}\n Green : {green}\n Red   : {red}')

# %% [markdown]
# ### Calling Function

# %%
ColorPalette()
# Out:
#  Blue  : 0
#  Green : 0
#  Red   : 102

# %%
#
